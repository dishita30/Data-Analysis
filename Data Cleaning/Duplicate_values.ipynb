# %%
import pandas as pd

# %%
data = pd.read_csv("googleplaystore.csv")

# %%
data.duplicated().sum()
# Out:
# 483

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Length: 10841, dtype: bool

# %%
data[data.duplicated(keep="last")]
# Out:
#                                 App             Category  Rating Reviews  \
# 164                    Ebook Reader  BOOKS_AND_REFERENCE     4.1   85842
# 192   Docs To Go™ Free Office Suite             BUSINESS     4.1  217730
# 193              Google My Business             BUSINESS     4.4   70991
# 204                             Box             BUSINESS     4.2  159872
# 213             ZOOM Cloud Meetings             BUSINESS     4.4   31614
# ...                             ...                  ...     ...     ...
# 3787     ABC News - US & World News   NEWS_AND_MAGAZINES     4.0   18976
# 3788                       NBC News   NEWS_AND_MAGAZINES     4.1   63020
# 3790                      USA TODAY   NEWS_AND_MAGAZINES     4.1   49259
# 3792   CNN Breaking US & World News   NEWS_AND_MAGAZINES     4.0  293080
# 3795   Newsroom: News Worth Sharing   NEWS_AND_MAGAZINES     4.2  201737
#
#                     Size     Installs  Type Price Content Rating  \
# ...

# %%
data.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
cities = ["New York", "Los Angeles", "Chicago","Housten","Phoenix","Los Angeles","Chicago"]
rankings =  [1,2,3,4,5,6,7]
scores = [9.8, 9.5 ,9.2,8.7,8.5,8.2,8.1]

df = {"Cities" : cities, 'Rankings' : rankings , "Scores" : scores}
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#         Cities  Rankings  Scores
# 0     New York         1     9.8
# 1  Los Angeles         2     9.5
# 2      Chicago         3     9.2
# 3      Housten         4     8.7
# 4      Phoenix         5     8.5
# 5  Los Angeles         6     8.2
# 6      Chicago         7     8.1

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1["Cities"].duplicated().sum()
# Out:
# 2

# %%
df1.drop_duplicates(subset="Cities", keep="last")
# Out:
#         Cities  Rankings  Scores
# 0     New York         1     9.8
# 3      Housten         4     8.7
# 4      Phoenix         5     8.5
# 5  Los Angeles         6     8.2
# 6      Chicago         7     8.1

# %% [markdown]
# keeping last duplicate data only, deleting rest all

# %%
df1.head()
# Out:
# 0       New York
# 3        Housten
# 4        Phoenix
# 5    Los Angeles
# 6        Chicago
# Name: Cities, dtype: object

# %%
data.duplicated(["App"]).sum()
# Out:
# 1181

# %%
df2 = data.copy()

# %% [markdown]
# if keep = last, then only last duplicated values are kept. if keep = false, then no values to be kept

# %%
df2.drop_duplicates(subset="App", keep = "last")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
